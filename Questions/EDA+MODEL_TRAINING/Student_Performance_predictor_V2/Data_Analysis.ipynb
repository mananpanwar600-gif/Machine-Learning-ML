# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Students_Performance_dataset.csv')
df.head()
# Out:
#    University Admission year  Gender  Age  H.S.C passing year Program  \
# 0                       2018    Male   24                2016    BCSE
# 1                       2021    Male   22                2020    BCSE
# 2                       2020  Female   21                2019    BCSE
# 3                       2021    Male   20                2020    BCSE
# 4                       2021    Male   22                2019    BCSE
#
#    Current Semester Do you have meritorious scholarship ?  \
# 0                12                                   Yes
# 1                 4                                   Yes
# 2                 5                                    No
# 3                 4                                   Yes
# 4                 4                                   Yes
#
#   Do you use University transportation?  How many hour do you study daily?  \
# 0                                    No                                  3
# ...

# %%
df.columns
# Out:
# Index(['University Admission year', 'Gender', 'Age', 'H.S.C passing year',
#        'Program', 'Current Semester', 'Do you have meritorious scholarship ?',
#        'Do you use University transportation?',
#        'How many hour do you study daily?',
#        'How many times do you seat for study in a day?',
#        'What is your preferable learning mode?', 'Do you use smart phone?',
#        'Do you have personal Computer?',
#        'How many hour do you spent daily in social media?',
#        'Status of your English language proficiency',
#        'Average attendance on class', 'Did you ever fall in probation?',
#        'Did you ever got suspension?',
#        'Do you attend in teacher consultancy for any kind of academical problems?',
#        'What are the skills do you have ?',
#        'How many hour do you spent daily on your skill development?',
#        'What is you interested area?', 'What is your relationship status?',
# ...

# %%
df.shape
# Out:
# (1194, 31)

# %% [markdown]
# ## Checking Missing Values

# %%
df.isna().sum()
# Out:
# University Admission year                                                    0
# Gender                                                                       0
# Age                                                                          0
# H.S.C passing year                                                           0
# Program                                                                      0
# Current Semester                                                             0
# Do you have meritorious scholarship ?                                        0
# Do you use University transportation?                                        0
# How many hour do you study daily?                                            0
# How many times do you seat for study in a day?                               0
# What is your preferable learning mode?                                       0
# Do you use smart phone?                                                      0
# ...

# %%
df=df.dropna()
'''

Dropping will be the best option here as we have only one column have a missing value so not much info will be lost!!

'''

# %%
df.shape
# Out:
# (1193, 31)

# %% [markdown]
# ## Finding all unique values in each columns

# %%
for value in df.columns:
    print(f"{value} : {df[value].unique()}\n")
# Out:
# University Admission year : [2018 2021 2020 2022 2019 2017 2015 2016 2014 2013 2023]
#
# Gender : <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str
#
# Age : [24 22 21 20 19 25 23 26 27 18]
#
# H.S.C passing year : [2016 2020 2019 2018 2021 2017 2022 2012 2014 2015 2028 2013]
#
# Program : <StringArray>
# ['BCSE']
# Length: 1, dtype: str
#
# Current Semester : [12  4  5  2 11  8 10 13  9 15 14 21  6  7 22  1 18 17  3 19 16 24]
#
# Do you have meritorious scholarship ? : <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
#
# Do you use University transportation? : <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
#
# How many hour do you study daily? : [ 3  1  2  5  6  4  8  7  9  0 10 13]
#
# How many times do you seat for study in a day? : [2 3 1 4 5 7 0 6]
#
# What is your preferable learning mode? : <StringArray>
# ['Offline', 'Online']
# Length: 2, dtype: str
#
# Do you use smart phone? : <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
#
# ...
